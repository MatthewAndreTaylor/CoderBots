# %% [markdown]
# # Example usage

# %%
# %pip install coderbot_sim

# %%
from coderbot_sim.simple_amr import RobotSim, example_maps

widget = RobotSim(example_maps.gen_simple_map(), debugDraw=False, show_controls=True)
widget.render()

res = await widget.step(0.5, forward=True)
print(res)

res = await widget.step(0.5, left=True)
print(res)

# %%
res = await widget.step(0.5, left=True)
print(res)
