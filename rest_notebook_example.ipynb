# %%
from rest_client import RobotPanel

robot_panel = RobotPanel()


robot_panel.controls = True

robot_panel.show()
# Out:
# RobotPanel(controls=True)

# %%
for step in robot_panel.step(num_steps=25):
    print(step)
# Out:
# {'pos': [41.16999816894531, 50.0]}
# {'pos': [42.31074905395508, 50.0]}
# {'pos': [43.42298126220703, 50.0]}
# {'pos': [44.507408142089844, 50.0]}
# {'pos': [45.56472396850586, 50.0]}
# {'pos': [46.59560775756836, 50.0]}
# {'pos': [47.6007194519043, 50.0]}
# {'pos': [48.58070373535156, 50.0]}
# {'pos': [49.53618621826172, 50.0]}
# {'pos': [50.46778106689453, 50.0]}
# {'pos': [51.3760871887207, 50.0]}
# {'pos': [52.26168441772461, 50.0]}
# {'pos': [53.12514114379883, 50.0]}
# {'pos': [53.96701431274414, 50.0]}
# {'pos': [54.787837982177734, 50.0]}
# {'pos': [55.58814239501953, 50.0]}
# {'pos': [56.368438720703125, 50.0]}
# {'pos': [57.12922668457031, 50.0]}
# {'pos': [57.87099838256836, 50.0]}
# {'pos': [58.59422302246094, 50.0]}
# {'pos': [59.29936981201172, 50.0]}
# {'pos': [59.98688507080078, 50.0]}
# {'pos': [60.6572151184082, 50.0]}
# {'pos': [61.310787200927734, 50.0]}
# {'pos': [61.94801712036133, 50.0]}

# %%
from rest_client import RobotPanel

robot_panel = RobotPanel()
robot_panel.show()

sensor_data = robot_panel.sensor()

points = sensor_data.get("hit_points", [])
tags = sensor_data.get("tags", [])

goal_points = []

for tag, point in zip(tags, points):
    if tag == "goal":
        print(f"Goal Point: {point}")
        goal_points.append(point)

robot_step = robot_panel.robot_env()
robot_state = robot_step["robot"]

print(f"My Robot: {robot_state}")

diff_x = goal_points[-1][0] - robot_state["pos"][0]
diff_y = goal_points[-1][1] - robot_state["pos"][1]

print(f"Diff X: {diff_x}, Diff Y: {diff_y}")

# normalize
norm = (diff_x**2 + diff_y**2)**0.5
if norm > 0:
    diff_x /= norm
    diff_y /= norm

# choose the direction of movement
robot_panel.move(diff_x, diff_y, 0.0)

# We create a stream for the robot's steps
# Latency on the first step is higher (may want to look at websockets)
for step in robot_panel.step(num_steps=25):
    print(step)

sensor_data = robot_panel.sensor()
print(sensor_data)
# Out:
# RobotPanel(endpoint='localhost:5000')
# Goal Point: [40.520853872564615, 30.999998928736936]
# My Robot: {'pos': [40.0, 50.0]}
# Diff X: 0.520853872564615, Diff Y: -19.000001071263064
# {'pos': [40.03206253051758, 48.830440521240234]}
# {'pos': [40.063323974609375, 47.69011688232422]}
# {'pos': [40.09380340576172, 46.578304290771484]}
# {'pos': [40.12351989746094, 45.494285583496094]}
# {'pos': [40.15249252319336, 44.4373664855957]}
# {'pos': [40.18074035644531, 43.4068717956543]}
# {'pos': [40.208282470703125, 42.402137756347656]}
# {'pos': [40.235137939453125, 41.422523498535156]}
# {'pos': [40.261322021484375, 40.46739959716797]}
# {'pos': [40.28684997558594, 39.53615188598633]}
# {'pos': [40.31174087524414, 38.6281852722168]}
# {'pos': [40.33600997924805, 37.742919921875]}
# {'pos': [40.35967254638672, 36.87978744506836]}
# {'pos': [40.38274383544922, 36.038230895996094]}
# {'pos': [40.405235290527344, 35.21771240234375]}
# {'pos': [40.42716598510742, 34.41770935058594]}
# {'pos': [40.44854736328125, 33.6377067565918]}
# {'pos': [40.46939468383789, 32.877201080322266]}
# {'pos': [40.489723205566406, 32.13570785522461]}
# {'pos': [40.50954055786133, 32.004844665527344]}
# {'pos': [40.52886199951172, 32.00487518310547]}
# {'pos': [40.54770278930664, 32.00490188598633]}
# {'pos': [40.566070556640625, 32.004920959472656]}
# {'pos': [40.583980560302734, 32.00493621826172]}
# {'pos': [40.601444244384766, 32.004947662353516]}
# {'hit_points': [[15.98286845306841, 31.96573876609216], [14.592040491661272, 29.184082279412266], [12.995896115374055, 25.991791154066362], [11.099112478249172, 22.198229473274516], [2.000001064705387, 14.424923828378372], [1.9999994921419244, 9.190427473479748], [39.25236159643854, 31.000000032972814], [39.51549502581656, 31.000000052409597], [39.724156557822944, 30.99999994768619], [39.897214525922045, 30.99999997985617], [40.04616299567195, 30.99999996638189], [40.17850504982925, 31.000000020288542], [40.29945736764866, 30.999999983915366], [40.41288453418682, 31.000000004978055], [40.52185323883399, 30.99999998431833], [40.628993237614395, 30.99999996311136], [40.73676268876481, 31.000000051480168], [40.8476783417473, 31.000000010917024], [40.96455749433078, 30.999999974940007], [55.456431531199435, 1.5000013716779392], [59.70993237484151, 1.5000010086651692], [64.57362990771729, 1.5000002274778161], [70.32893430208645, 1.499999084168099], [77.42202910497625, 1.5000010180816972], [78.0000010829168, 7.211648812939885], [77.99999967360698, 12.583169159296677], [69.8569623000005, 20.572157521287615], [68.92904887883519, 24.283813093413805], [68.1060427122883, 27.575836281035937], [67.35506116479598, 30.579765282359155], [66.65183496193207, 33.39266873023992], [65.97718795419524, 36.09124601008891], [65.31476325028522, 38.74095178808304], [77.99999936321348, 46.6199625610755], [77.99999967360698, 51.42672616541036], [78.0000010829168, 56.79824651176715], [71.97842156753708, 57.99999968896361], [65.93397937702304, 58.000000728597804], [61.029548657983824, 58.00000126667146], [56.88490656876306, 58.00000002606089], [53.26024946419169, 58.00000009010531], [49.994120555181624, 58.00000110246401], [46.97079896756722, 57.99999927701284], [44.10173603597589, 57.999998739351035], [41.314056008364474, 58.00000115469221], [38.54265818008543, 57.999998994742015], [35.72395701808527, 57.99999908029891], [32.7899288267547, 57.999998735023254], [29.66124646581266, 57.99999873075798], [26.23794470064334, 58.00000117088244], [22.385083489495855, 58.00000161168539], [17.908584219840094, 57.9999982828715], [12.511118773312571, 57.999998777101325], [5.704626643184746, 58.000000059361696], [1.9999994921419173, 54.81946785122726], [2.000001064705394, 49.58497149632868], [19.508218465180455, 39.01643823045542], [18.418468609439977, 36.83693664112927], [17.267804690180878, 34.53561144466304], [16.02204728144784, 32.04409416026045]], 'tags': ['obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle']}
