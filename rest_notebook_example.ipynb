# %%
from rest_client import RobotPanel

robot_panel = RobotPanel()

robot_panel.controls = True

robot_panel.show()
# Out:
# RobotPanel(controls=True)

# %%
for step in robot_panel.step(num_steps=25):
    print(step)
# Out:
# {'pos': [41.16999816894531, 50.0]}
# {'pos': [42.31074905395508, 50.0]}
# {'pos': [43.42298126220703, 50.0]}
# {'pos': [44.507408142089844, 50.0]}
# {'pos': [45.56472396850586, 50.0]}
# {'pos': [46.59560775756836, 50.0]}
# {'pos': [47.6007194519043, 50.0]}
# {'pos': [48.58070373535156, 50.0]}
# {'pos': [49.53618621826172, 50.0]}
# {'pos': [50.46778106689453, 50.0]}
# {'pos': [51.3760871887207, 50.0]}
# {'pos': [52.26168441772461, 50.0]}
# {'pos': [53.12514114379883, 50.0]}
# {'pos': [53.96701431274414, 50.0]}
# {'pos': [54.787837982177734, 50.0]}
# {'pos': [55.58814239501953, 50.0]}
# {'pos': [56.368438720703125, 50.0]}
# {'pos': [57.12922668457031, 50.0]}
# {'pos': [57.87099838256836, 50.0]}
# {'pos': [58.59422302246094, 50.0]}
# {'pos': [59.29936981201172, 50.0]}
# {'pos': [59.98688507080078, 50.0]}
# {'pos': [60.6572151184082, 50.0]}
# {'pos': [61.310787200927734, 50.0]}
# {'pos': [61.94801712036133, 50.0]}

# %%
from rest_client import RobotPanel

robot_panel = RobotPanel()

robot_panel.show()

sensor_data = robot_panel.sensor()

points = sensor_data.get("hit_points", [])
tags = sensor_data.get("tags", [])

goal_points = []

for tag, point in zip(tags, points):
    if tag == "goal":
        print(f"Goal Point: {point}")
        goal_points.append(point)

robot_step = robot_panel.robot_env()
robot_state = robot_step["robot"]

print(f"My Robot: {robot_state}")

diff_x = goal_points[-1][0] - robot_state["pos"][0]
diff_y = goal_points[-1][1] - robot_state["pos"][1]

print(f"Diff X: {diff_x}, Diff Y: {diff_y}")

# normalize
norm = (diff_x**2 + diff_y**2)**0.5
if norm > 0:
    diff_x /= norm
    diff_y /= norm

# choose the direction of movement
robot_panel.move(diff_x, diff_y, 0.0)

# We create a stream for the robot's steps
# Latency on the first step is higher (may want to look at websockets)
for step in robot_panel.step(num_steps=25):
    print(step)

sensor_data = robot_panel.sensor()
print(sensor_data)
# Out:
# RobotPanel()
# Goal Point: [38.614014774647444, 32.499999536749684]
# Goal Point: [40.47973382730729, 32.499999111307474]
# Goal Point: [42.356414166403894, 32.49999992532484]
# My Robot: {'pos': [40.0, 50.0]}
# Diff X: 2.3564141664038942, Diff Y: -17.500000074675157
# {'pos': [40.15613555908203, 48.8404655456543]}
# {'pos': [40.30836486816406, 47.70991897583008]}
# {'pos': [40.456790924072266, 46.607635498046875]}
# {'pos': [40.601505279541016, 45.53290939331055]}
# {'pos': [40.74260330200195, 44.485050201416016]}
# {'pos': [40.88017272949219, 43.4633903503418]}
# {'pos': [41.01430130004883, 42.46726989746094]}
# {'pos': [41.145076751708984, 41.49605178833008]}
# {'pos': [41.2725830078125, 40.54911422729492]}
# {'pos': [41.39690399169922, 39.625850677490234]}
# {'pos': [41.51811599731445, 38.725669860839844]}
# {'pos': [41.636295318603516, 37.847991943359375]}
# {'pos': [41.751522064208984, 36.99225616455078]}
# {'pos': [41.863868713378906, 36.15791320800781]}
# {'pos': [41.97340774536133, 35.34442901611328]}
# {'pos': [42.08020782470703, 34.5512809753418]}
# {'pos': [42.1843376159668, 33.77796173095703]}
# {'pos': [42.28586196899414, 33.504844665527344]}
# {'pos': [42.384849548339844, 33.50487518310547]}
# {'pos': [42.481361389160156, 33.50490188598633]}
# {'pos': [42.575462341308594, 33.504920959472656]}
# {'pos': [42.66720962524414, 33.504920959472656]}
# {'pos': [42.75666427612305, 33.504920959472656]}
# {'pos': [42.8438835144043, 33.504920959472656]}
# {'pos': [42.92892074584961, 33.504920959472656]}
# {'hit_points': [[16.731596868007593, 33.46319766227795], [15.251579952921531, 30.503158470916446], [38.31547148523442, 32.50000005308546], [39.905736806761276, 32.49999995324833], [40.72235939908137, 32.49999995466073], [41.22862629344753, 32.49999996855293], [41.57987394805724, 32.500000035295805], [41.84300040700982, 32.50000007510075], [42.051656409803684, 32.49999999321175], [42.22470980059989, 32.50000006666681], [42.373654304537666, 32.50000006192692], [42.50000002025679, 32.4857605757435], [42.50000003020616, 32.07756463830184], [42.49999999499739, 31.21894532174936], [42.49999998487628, 28.089196911027976], [43.806283163407706, 1.5000002867904954], [47.238455126745066, 1.4999987931037353], [50.77082468029949, 1.4999995203711265], [54.49311561547963, 1.4999999251629816], [58.5143510458582, 1.4999986367975495], [62.97700207092301, 1.5000000491990733], [68.07985274498614, 1.500002036066654], [74.11815276125249, 1.500001708764934], [77.99999816512052, 4.449398091420104], [77.99999953909015, 10.25461904952665], [77.99999910863397, 15.291845400593694], [69.18935416853563, 23.242582628486524], [68.35643779673947, 26.574250913860503], [67.61768618601863, 29.52924786868612], [66.94358862850223, 32.22564415628043], [66.31235775101979, 34.75057168784394], [65.70678064911937, 37.17287774340309], [65.11217224131948, 39.55131535756642], [77.99999617171385, 47.210377981397876], [77.99999910863397, 51.71799651835162], [77.99999953909015, 56.75522286941866], [72.49537934438985, 58.000002866057365], [66.79971132082625, 58.000000685237836], [62.17827652184181, 58.00000014618341], [58.27279185320258, 58.000002223637765], [54.85728458345822, 58.00000070449964], [51.77961829060884, 58.00000074773291], [48.930749666043, 58.00000081346889], [46.227237951422566, 58.000000036304144], [43.600413179162615, 58.00000033648007], [40.98893104959603, 58.000002120603085], [38.332875301053605, 58.000000518569735], [35.56814671516419, 58.0000011881052], [32.619996352695296, 58.00000061746978], [29.394227574866726, 58.00000115422404], [25.763685682248948, 58.00000082395701], [21.545487830966053, 58.00000093007243], [16.459469177385735, 58.000000135758775], [10.04572562384169, 58.000002142699095], [1.9999961892865272, 57.69504600784521], [1.9999986965840932, 52.144934540720726], [1.9999976415627145, 47.10989353750292], [19.323388092977332, 38.64677728631859], [18.098934351725173, 36.19787192997516], [16.773288401506537, 33.54657785644073]], 'tags': ['obstacle', 'obstacle', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'goal', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle', 'obstacle']}
