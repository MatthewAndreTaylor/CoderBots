# %%
from coderbot_sim.maze_runner.widget import MazeRunnerSim

sim = MazeRunnerSim()
sim.render()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from coderbot_sim.maze_runner.widget import MazeRunnerSim
#       3 sim = MazeRunnerSim()
#       4 sim.render()
#
# ImportError: cannot import name 'MazeRunnerSim' from 'coderbot_sim.maze_runner.widget' (c:\Users\hamza\CoderBots\coderbot_sim\maze_runner\widget.py)
